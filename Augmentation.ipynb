# %% [markdown]
# # Augmentation
# Testing and visualizing augmentation parameters.

# %%
from helper_functions import visualize_augmentation

visualize_augmentation("./features/mel_spectrograms/1003_IEO_HAP_HI.npy", noise_std=0.005, freq_mask=10, time_mask=20)
